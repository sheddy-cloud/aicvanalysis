# %%
import joblib
import pandas as pd
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Fine Tuning Model and exportation

# %%
df = pd.read_csv('../dataset/preprocessed/mbti_lemmatized.csv')
df
# Out:
#       type                                              posts
# 0     INFJ      intj moment      sportscenter play      pr...
# 1     ENTP    m find lack post alarming Sex boring s posit...
# 2     INTP    good             course   know   s blessing ...
# 3     INTJ    Dear INTP     enjoy conversation day    esot...
# 4     ENTJ    fire s silly misconception   approach logica...
# ...    ...                                                ...
# 8670  ISFP      think cat Fi dom reason       website have...
# 8671  ENFP       thread exist someplace        heck delete...
# 8672  INTP    question thing    purple pill   pick win lot...
# 8673  INFP    conflicted right come want child    honestly...
# 8674  INFP    long personalitycafe    doesn t change bit  ...
#
# [8675 rows x 2 columns]

# %%
encoder = LabelEncoder()

def train_test_evaluate_report(model, X_train, X_test, y_train, y_test):
    # Encode target
    y_train = encoder.fit_transform(y_train)
    y_test = encoder.transform(y_test)
    
    # Train model
    model.fit(X_train, y_train)
    
    joblib.dump(encoder, 'label_encoder.pkl')
    # Get classification report
    report = classification_report(y_test, model.predict(X_test), target_names=encoder.inverse_transform([i for i in range(16)]))
    print(report)
    
    return model.score(X_test, y_test)

# Define the pipeline
def create_pipeline():
    return Pipeline([
        ('vectorizer', TfidfVectorizer(max_features=5000)),
        ('classifier', LogisticRegression())
    ])

# %% [markdown]
# ## Logistic Regresssion

# %%
# Define parameter grid for grid search
param_grid = {
    'classifier__C': [0.1, 1, 10],
    'classifier__solver': ['lbfgs', 'liblinear'],
    'classifier__max_iter': [1000, 2000, 5000, 10000]
}

# Setup cross-validation and GridSearchCV
folds = StratifiedKFold(n_splits=5)
report = pd.read_csv('./report.csv')
score = []

for train_index, test_index in folds.split(X=df.posts, y=df.type):
    X_train, X_test, y_train, y_test = df.posts[train_index], df.posts[test_index], df.type[train_index], df.type[test_index]

    # Create a pipeline
    pipeline = create_pipeline()
    
    # Set up GridSearchCV
    grid_search = GridSearchCV(pipeline, param_grid, cv=folds, n_jobs=-1, verbose=2)
    grid_search.fit(X_train, y_train)
    
    # Print the best parameters
    print(f"Best parameters: {grid_search.best_params_}")
    
    # Evaluate the model
    best_model = grid_search.best_estimator_
    score.append(train_test_evaluate_report(best_model, X_train, X_test, y_train, y_test))

# Saving the trained pipeline (best model)
joblib.dump(grid_search.best_estimator_, 'best_model_pipeline.pkl')
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=lbfgs; total time=  12.5s
# [CV] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=lbfgs; total time=  12.4s
# [CV] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=lbfgs; total time=  14.1s
# [CV] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=lbfgs; total time=  14.7s
# [CV] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear; total time=  11.9s
# [CV] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=lbfgs; total time=  15.0s
# [CV] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear; total time=  15.0s
# [CV] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear; total time=  16.1s
# [CV] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear; total time=  13.2s
# [CV] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear; total time=  13.6s
# [CV] END classifier__C=0.1, classifier__max_iter=2000, classifier__solver=lbfgs; total time=  15.2s
# [CV] END classifier__C=0.1, classifier__max_iter=2000, classifier__solver=lbfgs; total time=  13.8s
# [CV] END classifier__C=0.1, classifier__max_iter=2000, classifier__solver=lbfgs; total time=  13.6s
# [CV] END classifier__C=0.1, classifier__max_iter=2000, classifier__solver=lbfgs; total time=  13.5s
# [CV] END classifier__C=0.1, classifier__max_iter=2000, classifier__solver=lbfgs; total time=  14.6s
# [CV] END classifier__C=0.1, classifier__max_iter=2000, classifier__solver=liblinear; total time=  13.0s
# [CV] END classifier__C=0.1, classifier__max_iter=2000, classifier__solver=liblinear; total time=  16.2s
# [CV] END classifier__C=0.1, classifier__max_iter=2000, classifier__solver=liblinear; total time=  13.4s
# [CV] END classifier__C=0.1, classifier__max_iter=2000, classifier__solver=liblinear; total time=  16.8s
# [CV] END classifier__C=0.1, classifier__max_iter=2000, classifier__solver=liblinear; total time=  14.1s
# [CV] END classifier__C=0.1, classifier__max_iter=5000, classifier__solver=lbfgs; total time=  13.5s
# [CV] END classifier__C=0.1, classifier__max_iter=5000, classifier__solver=lbfgs; total time=  13.5s
# [CV] END classifier__C=0.1, classifier__max_iter=5000, classifier__solver=lbfgs; total time=  13.4s
# [CV] END classifier__C=0.1, classifier__max_iter=5000, classifier__solver=lbfgs; total time=  14.6s
# [CV] END classifier__C=0.1, classifier__max_iter=5000, classifier__solver=lbfgs; total time=  14.3s
# [CV] END classifier__C=0.1, classifier__max_iter=5000, classifier__solver=liblinear; total time=  13.6s
# [CV] END classifier__C=0.1, classifier__max_iter=5000, classifier__solver=liblinear; total time=  14.7s
# [CV] END classifier__C=0.1, classifier__max_iter=5000, classifier__solver=liblinear; total time=  14.3s
# [CV] END classifier__C=0.1, classifier__max_iter=5000, classifier__solver=liblinear; total time=  16.0s
# [CV] END classifier__C=0.1, classifier__max_iter=5000, classifier__solver=liblinear; total time=  14.8s
# [CV] END classifier__C=0.1, classifier__max_iter=10000, classifier__solver=lbfgs; total time=  13.9s
# [CV] END classifier__C=0.1, classifier__max_iter=10000, classifier__solver=lbfgs; total time=  14.0s
# [CV] END classifier__C=0.1, classifier__max_iter=10000, classifier__solver=lbfgs; total time=  14.1s
# [CV] END classifier__C=0.1, classifier__max_iter=10000, classifier__solver=lbfgs; total time=  14.6s
# [CV] END classifier__C=0.1, classifier__max_iter=10000, classifier__solver=lbfgs; total time=  14.5s
# [CV] END classifier__C=0.1, classifier__max_iter=10000, classifier__solver=liblinear; total time=  13.7s
# [CV] END classifier__C=0.1, classifier__max_iter=10000, classifier__solver=liblinear; total time=  13.9s
# [CV] END classifier__C=0.1, classifier__max_iter=10000, classifier__solver=liblinear; total time=  14.0s
# [CV] END classifier__C=0.1, classifier__max_iter=10000, classifier__solver=liblinear; total time=  15.1s
# [CV] END classifier__C=0.1, classifier__max_iter=10000, classifier__solver=liblinear; total time=  15.7s
# [CV] END classifier__C=1, classifier__max_iter=1000, classifier__solver=lbfgs; total time=  23.6s
# [CV] END classifier__C=1, classifier__max_iter=1000, classifier__solver=lbfgs; total time=  23.2s
# [CV] END classifier__C=1, classifier__max_iter=1000, classifier__solver=lbfgs; total time=  24.8s
# [CV] END classifier__C=1, classifier__max_iter=1000, classifier__solver=lbfgs; total time=  24.8s
# [CV] END classifier__C=1, classifier__max_iter=1000, classifier__solver=liblinear; total time=  19.8s
# [CV] END classifier__C=1, classifier__max_iter=1000, classifier__solver=liblinear; total time=  17.8s
# [CV] END classifier__C=1, classifier__max_iter=1000, classifier__solver=liblinear; total time=  20.4s
# [CV] END classifier__C=1, classifier__max_iter=1000, classifier__solver=lbfgs; total time=  24.2s
# [CV] END classifier__C=1, classifier__max_iter=1000, classifier__solver=liblinear; total time=  16.2s
# [CV] END classifier__C=1, classifier__max_iter=1000, classifier__solver=liblinear; total time=  16.8s
# [CV] END classifier__C=1, classifier__max_iter=2000, classifier__solver=lbfgs; total time=  20.1s
# [CV] END classifier__C=1, classifier__max_iter=2000, classifier__solver=lbfgs; total time=  22.7s
# [CV] END classifier__C=1, classifier__max_iter=2000, classifier__solver=lbfgs; total time=  14.0s
# [CV] END classifier__C=1, classifier__max_iter=2000, classifier__solver=lbfgs; total time=  15.3s
# [CV] END classifier__C=1, classifier__max_iter=2000, classifier__solver=liblinear; total time=  11.0s
# [CV] END classifier__C=1, classifier__max_iter=2000, classifier__solver=lbfgs; total time=  15.3s
# [CV] END classifier__C=1, classifier__max_iter=2000, classifier__solver=liblinear; total time=  10.7s
# [CV] END classifier__C=1, classifier__max_iter=2000, classifier__solver=liblinear; total time=  13.6s
# [CV] END classifier__C=1, classifier__max_iter=2000, classifier__solver=liblinear; total time=  14.4s
# [CV] END classifier__C=1, classifier__max_iter=2000, classifier__solver=liblinear; total time=  14.8s
# [CV] END classifier__C=1, classifier__max_iter=5000, classifier__solver=lbfgs; total time=  23.9s
# [CV] END classifier__C=1, classifier__max_iter=5000, classifier__solver=lbfgs; total time=257.1min
# [CV] END classifier__C=1, classifier__max_iter=5000, classifier__solver=lbfgs; total time=257.1min
# [CV] END classifier__C=1, classifier__max_iter=5000, classifier__solver=lbfgs; total time=257.0min
# [CV] END classifier__C=1, classifier__max_iter=5000, classifier__solver=lbfgs; total time

# [CV] END classifier__C=1, classifier__max_iter=5000, classifier__solver=lbfgs; total time=  20.7s
# [CV] END classifier__C=1, classifier__max_iter=5000, classifier__solver=lbfgs; total time=  26.4s
# [CV] END classifier__C=1, classifier__max_iter=5000, classifier__solver=lbfgs; total time=  23.7s
# [CV] END classifier__C=1, classifier__max_iter=5000, classifier__solver=lbfgs; total time=  22.1s
# [CV] END classifier__C=1, classifier__max_iter=5000, classifier__solver=liblinear; total time=  16.0s
# [CV] END classifier__C=1, classifier__max_iter=5000, classifier__solver=liblinear; total time=  18.8s
# [CV] END classifier__C=1, classifier__max_iter=5000, classifier__solver=lbfgs; total time=  25.7s
# [CV] END classifier__C=1, classifier__max_iter=5000, classifier__solver=liblinear; total time=  19.1s
# [CV] END classifier__C=1, classifier__max_iter=5000, classifier__solver=liblinear; total time=  17.3s
# [CV] END classifier__C=1, classifier__max_iter=5000, classifier__solver=liblinear; total time=  17.0s
# [CV] END classifier__C=1, classifier__max_iter=10000, classifier__solver=lbfgs; total time=  26.4s
# [CV] END classifier__C=1, classifier__max_iter=10000, classifier__solver=lbfgs; total time=  21.9s
# [CV] END classifier__C=1, classifier__max_iter=10000, classifier__solver=lbfgs; total time=  20.6s
# [CV] END classifier__C=1, classifier__max_iter=10000, classifier__solver=lbfgs; total time=  25.9s
# [CV] END classifier__C=1, classifier__max_iter=10000, classifier__solver=liblinear; total time=  19.2s
# [CV] END classifier__C=1, classifier__max_iter=10000, classifier__solver=lbfgs; total time=  21.6s
# ...
# [CV] END classifier__C=10, classifier__max_iter=5000, classifier__solver=liblinear; total time=  27.8s
# [CV] END classifier__C=10, classifier__max_iter=5000, classifier__solver=liblinear; total time=  24.4s
# [CV] END classifier__C=10, classifier__max_iter=5000, classifier__solver=liblinear; total time=  22.7s
# [CV] END classifier__C=10, classifier__max_iter=10000, classifier__solver=lbfgs; total time=  37.5s
# [CV] END classifier__C=10, classifier__max_iter=10000, classifier__solver=lbfgs; total time=  36.5s
# [CV] END classifier__C=10, classifier__max_iter=10000, classifier__solver=lbfgs; total time=  37.0s
# [CV] END classifier__C=10, classifier__max_iter=10000, classifier__solver=lbfgs; total time=  35.6s
# [CV] END classifier__C=10, classifier__max_iter=10000, classifier__solver=liblinear; total time=  25.0s
# [CV] END classifier__C=10, classifier__max_iter=10000, classifier__solver=liblinear; total time=  23.6s
# [CV] END classifier__C=10, classifier__max_iter=10000, classifier__solver=lbfgs; total time=  40.4s
# [CV] END classifier__C=10, classifier__max_iter=10000, classifier__solver=liblinear; total time=  23.2s
# [CV] END classifier__C=10, classifier__max_iter=10000, classifier__solver=liblinear; total time=  16.4s
# [CV] END classifier__C=10, classifier__max_iter=10000, classifier__solver=liblinear; total time=  13.7s
# Best parameters: {'classifier__C': 1, 'classifier__max_iter': 1000, 'classifier__solver': 'lbfgs'}
#               precision    recall  f1-score   support
#
#         ENFJ       0.73      0.21      0.33        38
#         ENFP       0.67      0.56      0.61       135
#         ENTJ       0.71      0.33      0.45        46
#         ENTP       0.68      0.61      0.64       137
#         ESFJ       0.50      0.11      0.18         9
#         ESFP       0.00      0.00      0.00        10
#         ESTJ       0.00      0.00      0.00         7
#         ESTP       0.75      0.17      0.27        18
#         INFJ       0.64      0.70      0.67       294
#         INFP       0.63      0.85      0.72       366
#         INTJ       0.62      0.66      0.64       218
#         INTP       0.63      0.77      0.69       261
#         ISFJ       1.00      0.18      0.31        33
#         ISFP       0.71      0.27      0.39        55
#         ISTJ       0.67      0.39      0.49        41
#         ISTP       0.79      0.51      0.62        67
#
#     accuracy                           0.65      1735
#    macro avg       0.61      0.39      0.44      1735
# weighted avg       0.65      0.65      0.63      1735
#
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=lbfgs; total time=  12.8s
# [CV] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=lbfgs; total time=  13.7s
# [CV] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=lbfgs; total time=  13.7s
# [CV] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=lbfgs; total time=  13.9s
# [CV] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear; total time=  14.1s
# [CV] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear; total time=  14.4s
# [CV] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear; total time=  14.7s
# [CV] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=lbfgs; total time=  16.6s
# [CV] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear; total time=  13.0s
# [CV] END classifier__C=0.1, classifier__max_iter=1000, classifier__solver=liblinear; total time=  14.3s
# [CV] END classifier__C=0.1, classifier__max_iter=2000, classifier__solver=lbfgs; total time=  14.2s
# [CV] END classifier__C=0.1, classifier__max_iter=2000, classifier__solver=lbfgs; total time=  14.0s
# [CV] END classifier__C=0.1, classifier__max_iter=2000, classifier__solver=lbfgs; total time=  13.8s
# [CV] END classifier__C=0.1, classifier__max_iter=2000, classifier__solver=liblinear; total time=  13.7s
# [CV] END classifier__C=0.1, classifier__max_iter=2000, classifier__solver=lbfgs; total time=  14.8s
# [CV] END classifier__C=0.1, classifier__max_iter=2000, classifier__solver=lbfgs; total time=  15.2s
# [CV] END classifier__C=0.1, classifier__max_iter=2000, classifier__solver=liblinear; total time=  14.9s
# [CV] END classifier__C=0.1, classifier__max_iter=2000, classifier__solver=liblinear; total time=  14.0s
# [CV] END classifier__C=0.1, classifier__max_iter=2000, classifier__solver=liblinear; total time=  15.7s
# [CV] END classifier__C=0.1, classifier__max_iter=2000, classifier__solver=liblinear; total time=  15.7s
# [CV] END classifier__C=0.1, classifier__max_iter=5000, classifier__solver=lbfgs; total time=  12.9s
# [CV] END classifier__C=0.1, classifier__max_iter=5000, classifier__solver=lbfgs; total time=  13.1s
# [CV] END classifier__C=0.1, classifier__max_iter=5000, classifier__solver=lbfgs; total time=  13.6s
# [CV] END classifier__C=0.1, classifier__max_iter=5000, classifier__solver=lbfgs; total time=  14.5s
# [CV] END classifier__C=0.1, classifier__max_iter=5000, classifier__solver=liblinear; total time=  13.1s
# [CV] END classifier__C=0.1, classifier__max_iter=5000, classifier__solver=lbfgs; total time=  16.4s
# [CV] END classifier__C=0.1, classifier__max_iter=5000, classifier__solver=liblinear; total time=  13.4s
# [CV] END classifier__C=0.1, classifier__max_iter=5000, classifier__solver=liblinear; total time=  14.8s
# [CV] END classifier__C=0.1, classifier__max_iter=5000, classifier__solver=liblinear; total time=  13.0s
# [CV] END classifier__C=0.1, classifier__max_iter=5000, classifier__solver=liblinear; total time=  14.1s
# [CV] END classifier__C=0.1, classifier__max_iter=10000, classifier__solver=lbfgs; total time=  14.2s
# [CV] END classifier__C=0.1, classifier__max_iter=10000, classifier__solver=lbfgs; total time=  14.5s
# [CV] END classifier__C=0.1, classifier__max_iter=10000, classifier__solver=lbfgs; total time=  12.6s
# [CV] END classifier__C=0.1, classifier__max_iter=10000, classifier__solver=lbfgs; total time=  14.3s
# [CV] END classifier__C=0.1, classifier__max_iter=10000, classifier__solver=liblinear; total time=  13.2s
# [CV] END classifier__C=0.1, classifier__max_iter=10000, classifier__solver=lbfgs; total time=  13.9s
# [CV] END classifier__C=0.1, classifier__max_iter=10000, classifier__solver=liblinear; total time=  13.8s
# [CV] END classifier__C=0.1, classifier__max_iter=10000, classifier__solver=liblinear; total time=  15.1s
# [CV] END classifier__C=0.1, classifier__max_iter=10000, classifier__solver=liblinear; total time=  15.0s
# [CV] END classifier__C=0.1, classifier__max_iter=10000, classifier__solver=liblinear; total time=  14.7s
# [CV] END classifier__C=1, classifier__max_iter=1000, classifier__solver=lbfgs; total time=  19.7s
# [CV] END classifier__C=1, classifier__max_iter=1000, classifier__solver=lbfgs; total time=  19.1s
# [CV] END classifier__C=1, classifier__max_iter=1000, classifier__solver=lbfgs; total time=  22.4s
# [CV] END classifier__C=1, classifier__max_iter=1000, classifier__solver=lbfgs; total time=  22.2s
# [CV] END classifier__C=1, classifier__max_iter=1000, classifier__solver=liblinear; total time=  18.3s
# [CV] END classifier__C=1, classifier__max_iter=1000, classifier__solver=lbfgs; total time=  26.8s
# [CV] END classifier__C=1, classifier__max_iter=1000, classifier__solver=liblinear; total time=  19.8s
# [CV] END classifier__C=1, classifier__max_iter=1000, classifier__solver=liblinear; total time=  20.1s
# [CV] END classifier__C=1, classifier__max_iter=1000, classifier__solver=liblinear; total time=  17.6s
# [CV] END classifier__C=1, classifier__max_iter=1000, classifier__solver=liblinear; total time=  22.2s
# [CV] END classifier__C=1, classifier__max_iter=2000, classifier__solver=lbfgs; total time=  26.0s
# [CV] END classifier__C=1, classifier__max_iter=2000, classifier__solver=lbfgs; total time=  26.4s
# [CV] END classifier__C=1, classifier__max_iter=2000, classifier__solver=lbfgs; total time=  30.3s
# [CV] END classifier__C=1, classifier__max_iter=2000, classifier__solver=lbfgs; total time=  25.8s
# [CV] END classifier__C=1, classifier__max_iter=2000, classifier__solver=liblinear; total time=  20.1s
# [CV] END classifier__C=1, classifier__max_iter=2000, classifier__solver=lbfgs; total time=  25.6s
# [CV] END classifier__C=1, classifier__max_iter=2000, classifier__solver=liblinear; total time=  20.0s
# [CV] END classifier__C=1, classifier__max_iter=2000, classifier__solver=liblinear; total time=  20.7s
# [CV] END classifier__C=1, classifier__max_iter=2000, classifier__solver=liblinear; total time=  20.2s
# [CV] END classifier__C=1, classifier__max_iter=2000, classifier__solver=liblinear; total time=  23.2s
# [CV] END classifier__C=1, classifier__max_iter=5000, classifier__solver=lbfgs; total time=  26.6s
# [CV] END classifier__C=1, classifier__max_iter=5000, classifier__solver=lbfgs; total time=  27.2s
# [CV] END classifier__C=1, classifier__max_iter=5000, classifier__solver=lbfgs; total time=  28.7s
# [CV] END classifier__C=1, classifier__max_iter=5000, classifier__solver=lbfgs; total time=  27.7s
# [CV] END classifier__C=1, classifier__max_iter=5000, classifier__solver=liblinear; total time=  17.7s
# [CV] END classifier__C=1, classifier__max_iter=5000, classifier__solver=lbfgs; total time=  28.8s
# [CV] END classifier__C=1, classifier__max_iter=5000, classifier__solver=liblinear; total time=  17.8s
# [CV] END classifier__C=1, classifier__max_iter=5000, classifier__solver=liblinear; total time=  24.6s
# [CV] END classifier__C=1, classifier__max_iter=5000, classifier__solver=liblinear; total time=  19.0s
# [CV] END classifier__C=1, classifier__max_iter=5000, classifier__solver=liblinear; total time=  19.0s
# [CV] END classifier__C=1, classifier__max_iter=10000, classifier__solver=lbfgs; total time=  27.8s
# [CV] END classifier__C=1, classifier__max_iter=10000, classifier__solver=lbfgs; total time=  29.8s
# [CV] END classifier__C=1, classifier__max_iter=10000, classifier__solver=lbfgs; total time=  25.8s
# [CV] END classifier__C=1, classifier__max_iter=10000, classifier__solver=lbfgs; total time=  29.3s
# [CV] END classifier__C=1, classifier__max_iter=10000, classifier__solver=liblinear; total time=  20.0s
# [CV] END classifier__C=1, classifier__max_iter=10000, classifier__solver=lbfgs; total time=  24.4s
# [CV] END classifier__C=1, classifier__max_iter=10000, classifier__solver=liblinear; total time=  20.4s
# [CV] END classifier__C=1, classifier__max_iter=10000, classifier__solver=liblinear; total time=  18.2s
# [CV] END classifier__C=1, classifier__max_iter=10000, classifier__solver=liblinear; total time=  21.3s
# [CV] END classifier__C=1, classifier__max_iter=10000, classifier__solver=liblinear; total time=  22.7s
# [CV] END classifier__C=10, classifier__max_iter=1000, classifier__solver=lbfgs; total time=  36.8s
# [CV] END classifier__C=10, classifier__max_iter=1000, classifier__solver=lbfgs; total time=  34.8s
# [CV] END classifier__C=10, classifier__max_iter=1000, classifier__solver=lbfgs; total time=  49.8s
# [CV] END classifier__C=10, classifier__max_iter=1000, classifier__solver=lbfgs; total time=  47.6s
# [CV] END classifier__C=10, classifier__max_iter=1000, classifier__solver=liblinear; total time=  25.8s
# [CV] END classifier__C=10, classifier__max_iter=1000, classifier__solver=lbfgs; total time=  47.4s
# [CV] END classifier__C=10, classifier__max_iter=1000, classifier__solver=liblinear; total time=  27.5s
# [CV] END classifier__C=10, classifier__max_iter=1000, classifier__solver=liblinear; total time=  29.6s
# [CV] END classifier__C=10, classifier__max_iter=1000, classifier__solver=liblinear; total time=  25.6s
# [CV] END classifier__C=10, classifier__max_iter=1000, classifier__solver=liblinear; total time=  25.9s
# [CV] END classifier__C=10, classifier__max_iter=2000, classifier__solver=lbfgs; total time=  43.5s
# [CV] END classifier__C=10, classifier__max_iter=2000, classifier__solver=lbfgs; total time=  42.7s
# [CV] END classifier__C=10, classifier__max_iter=2000, classifier__solver=lbfgs; total time=  45.4s
# [CV] END classifier__C=10, classifier__max_iter=2000, classifier__solver=lbfgs; total time=  39.7s
# [CV] END classifier__C=10, classifier__max_iter=2000, classifier__solver=liblinear; total time=  26.0s
# [CV] END classifier__C=10, classifier__max_iter=2000, classifier__solver=liblinear; total time=  25.9s
# [CV] END classifier__C=10, classifier__max_iter=2000, classifier__solver=liblinear; total time=  30.2s
# [CV] END classifier__C=10, classifier__max_iter=2000, classifier__solver=lbfgs; total time=  49.5s
# [CV] END classifier__C=10, classifier__max_iter=2000, classifier__solver=liblinear; total time=  25.7s
# [CV] END classifier__C=10, classifier__max_iter=2000, classifier__solver=liblinear; total time=  30.2s
# [CV] END classifier__C=10, classifier__max_iter=5000, classifier__solver=lbfgs; total time=  43.4s
# [CV] END classifier__C=10, classifier__max_iter=5000, classifier__solver=lbfgs; total time=  40.2s
# [CV] END classifier__C=10, classifier__max_iter=5000, classifier__solver=lbfgs; total time=  38.9s
# [CV] END classifier__C=10, classifier__max_iter=5000, classifier__solver=lbfgs; total time=  47.9s
# [CV] END classifier__C=10, classifier__max_iter=5000, classifier__solver=liblinear; total time=  26.7s
# [CV] END classifier__C=10, classifier__max_iter=5000, classifier__solver=liblinear; total time=  28.1s
# [CV] END classifier__C=10, classifier__max_iter=5000, classifier__solver=lbfgs; total time=  46.1s
# [CV] END classifier__C=10, classifier__max_iter=5000, classifier__solver=liblinear; total time=  28.0s
# [CV] END classifier__C=10, classifier__max_iter=5000, classifier__solver=liblinear; total time=  26.0s
# [CV] END classifier__C=10, classifier__max_iter=5000, classifier__solver=liblinear; total time=  28.0s
# [CV] END classifier__C=10, classifier__max_iter=10000, classifier__solver=lbfgs; total time=  41.3s
# [CV] END classifier__C=10, classifier__max_iter=10000, classifier__solver=lbfgs; total time=  45.4s
# [CV] END classifier__C=10, classifier__max_iter=10000, classifier__solver=lbfgs; total time=  42.6s
# [CV] END classifier__C=10, classifier__max_iter=10000, classifier__solver=lbfgs; total time=  38.2s
# [CV] END classifier__C=10, classifier__max_iter=10000, classifier__solver=liblinear; total time=  31.6s
# [CV] END classifier__C=10, classifier__max_iter=10000, classifier__solver=liblinear; total time=  28.0s
# [CV] END classifier__C=10, classifier__max_iter=10000, classifier__solver=liblinear; total time=  27.1s
# [CV] END classifier__C=10, classifier__max_iter=10000, classifier__solver=lbfgs; total time=  44.1s
# [CV] END classifier__C=10, classifier__max_iter=10000, classifier__solver=liblinear; total time=  17.6s
# [CV] END classifier__C=10, classifier__max_iter=10000, classifier__solver=liblinear; total time=  17.2s
# Best parameters: {'classifier__C': 10, 'classifier__max_iter': 1000, 'classifier__solver': 'liblinear'}
#               precision    recall  f1-score   support
#
#         ENFJ       0.62      0.26      0.37        38
#         ENFP       0.63      0.56      0.59       135
#         ENTJ       0.59      0.35      0.44        46
#         ENTP       0.63      0.57      0.60       137
#         ESFJ       0.00      0.00      0.00         9
#         ESFP       0.00      0.00      0.00         9
#         ESTJ       1.00      0.12      0.22         8
#         ESTP       0.80      0.22      0.35        18
#         INFJ       0.62      0.67      0.65       294
#         INFP       0.61      0.78      0.69       366
#         INTJ       0.65      0.63      0.64       219
#         INTP       0.65      0.76      0.70       260
#         ISFJ       0.85      0.52      0.64        33
#         ISFP       0.67      0.52      0.58        54
#         ISTJ       0.81      0.41      0.55        41
#         ISTP       0.68      0.65      0.66        68
#
#     accuracy                           0.64      1735
#    macro avg       0.61      0.44      0.48      1735
# weighted avg       0.64      0.64      0.63      1735
# ['best_model_pipeline.pkl']

# %%
dir(grid_search.best_estimator_)
# Out:
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__sklearn_clone__',
#  '__sklearn_is_fitted__',
#  '__sklearn_tags__',
#  '__slotnames__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_build_request_for_signature',
#  '_can_fit_transform',
#  '_can_inverse_transform',
#  '_can_transform',
#  '_check_feature_names',
#  '_check_method_params',
#  '_check_n_features',
#  '_doc_link_module',
#  '_doc_link_template',
#  '_doc_link_url_param_generator',
#  '_estimator_type',
#  '_final_estimator',
#  '_fit',
#  '_get_default_requests',
#  '_get_doc_link',
#  '_get_metadata_for_step',
#  '_get_metadata_request',
#  '_get_param_names',
#  '_get_params',
#  '_get_tags',
#  '_iter',
#  '_log_message',
#  '_more_tags',
#  '_parameter_constraints',
#  '_replace_estimator',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
#  '_set_params',
#  '_sk_visual_block_',
#  '_validate_data',
#  '_validate_names',
#  '_validate_params',
#  '_validate_steps',
#  'classes_',
#  'decision_function',
#  'feature_names_in_',
#  'fit',
#  'fit_predict',
#  'fit_transform',
#  'get_feature_names_out',
#  'get_metadata_routing',
#  'get_params',
#  'inverse_transform',
#  'memory',
#  'n_features_in_',
#  'named_steps',
#  'predict',
#  'predict_log_proba',
#  'predict_proba',
#  'score',
#  'score_samples',
#  'set_output',
#  'set_params',
#  'set_score_request',
#  'steps',
#  'transform',
#  'transform_input',
#  'verbose']

# %%
grid_search.best_score_
# Out:
# 0.6557636887608069

# %%
grid_search.best_estimator_.predict(["I feel so tired today"])
# Out:
# array([9])

# %%
grid_search.best_params_
# Out:
# {'classifier__C': 10,
#  'classifier__max_iter': 1000,
#  'classifier__solver': 'liblinear'}

# %%
# Define parameter grid for grid search
param_grid = {
    'classifier__C': [10],
    'classifier__solver': ['liblinear'],
    'classifier__max_iter': [1000]
}

# Setup cross-validation and GridSearchCV
folds = StratifiedKFold(n_splits=5)
report = pd.read_csv('./report.csv')
score = []

for train_index, test_index in folds.split(X=df.posts, y=df.type):
    X_train, X_test, y_train, y_test = df.posts[train_index], df.posts[test_index], df.type[train_index], df.type[test_index]

    # Create a pipeline
    pipeline = create_pipeline()
    
    # Set up GridSearchCV
    grid_search = GridSearchCV(pipeline, param_grid, cv=folds, n_jobs=-1, verbose=2)
    grid_search.fit(X_train, y_train)
    
    # Print the best parameters
    print(f"Best parameters: {grid_search.best_params_}")
    
    # Evaluate the model
    best_model = grid_search.best_estimator_
    score.append(train_test_evaluate_report(best_model, X_train, X_test, y_train, y_test))

# Saving the trained pipeline (best model)
joblib.dump(grid_search.best_estimator_, 'best_model_pipeline.pkl')
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END classifier__C=10, classifier__max_iter=1000, classifier__solver=liblinear; total time=  25.2s
# [CV] END classifier__C=10, classifier__max_iter=1000, classifier__solver=liblinear; total time=  25.4s
# [CV] END classifier__C=10, classifier__max_iter=1000, classifier__solver=liblinear; total time=  25.7s
# [CV] END classifier__C=10, classifier__max_iter=1000, classifier__solver=liblinear; total time=  26.2s
# [CV] END classifier__C=10, classifier__max_iter=1000, classifier__solver=liblinear; total time=  10.5s
# Best parameters: {'classifier__C': 10, 'classifier__max_iter': 1000, 'classifier__solver': 'liblinear'}
#               precision    recall  f1-score   support
#
#         ENFJ       0.79      0.29      0.42        38
#         ENFP       0.66      0.60      0.63       135
#         ENTJ       0.79      0.40      0.54        47
#         ENTP       0.62      0.62      0.62       137
#         ESFJ       1.00      0.12      0.22         8
#         ESFP       1.00      0.11      0.20         9
#         ESTJ       1.00      0.12      0.22         8
#         ESTP       1.00      0.33      0.50        18
#         INFJ       0.63      0.71      0.67       294
#         INFP       0.67      0.81      0.73       366
#         INTJ       0.61      0.63      0.62       218
#         INTP       0.64      0.73      0.68       261
#         ISFJ       0.80      0.48      0.60        33
#         ISFP       0.63      0.35      0.45        54
#         ISTJ       0.70      0.51      0.59        41
#         ISTP       0.80      0.57      0.67        68
#
#     accuracy                           0.65      1735
#    macro avg       0.77      0.46      0.52      1735
# weighted avg       0.67      0.65      0.64      1735
#
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END classifier__C=10, classifier__max_iter=1000, classifier__solver=liblinear; total time=  24.8s
# [CV] END classifier__C=10, classifier__max_iter=1000, classifier__solver=liblinear; total time=  24.8s
# [CV] END classifier__C=10, classifier__max_iter=1000, classifier__solver=liblinear; total time=  25.1s
# [CV] END classifier__C=10, classifier__max_iter=1000, classifier__solver=liblinear; total time=  25.8s
# [CV] END classifier__C=10, classifier__max_iter=1000, classifier__solver=liblinear; total time=  10.1s
# Best parameters: {'classifier__C': 10, 'classifier__max_iter': 1000, 'classifier__solver': 'liblinear'}
#               precision    recall  f1-score   support
#
#         ENFJ       0.57      0.21      0.31        38
#         ENFP       0.71      0.67      0.69       135
#         ENTJ       0.72      0.50      0.59        46
#         ENTP       0.73      0.60      0.66       137
#         ESFJ       1.00      0.12      0.22         8
#         ESFP       0.00      0.00      0.00        10
#         ESTJ       1.00      0.25      0.40         8
#         ESTP       0.86      0.35      0.50        17
#         INFJ       0.64      0.65      0.64       294
#         INFP       0.64      0.82      0.72       367
#         INTJ       0.62      0.69      0.66       218
#         INTP       0.63      0.72      0.67       261
#         ISFJ       0.86      0.53      0.65        34
#         ISFP       0.71      0.44      0.55        54
#         ISTJ       0.85      0.54      0.66        41
#         ISTP       0.72      0.58      0.64        67
#
#     accuracy                           0.66      1735
#    macro avg       0.70      0.48      0.53      1735
# weighted avg       0.67      0.66      0.65      1735
#
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END classifier__C=10, classifier__max_iter=1000, classifier__solver=liblinear; total time=  27.6s
# [CV] END classifier__C=10, classifier__max_iter=1000, classifier__solver=liblinear; total time=  31.1s
# [CV] END classifier__C=10, classifier__max_iter=1000, classifier__solver=liblinear; total time=  31.7s
# [CV] END classifier__C=10, classifier__max_iter=1000, classifier__solver=liblinear; total time=  32.1s
# [CV] END classifier__C=10, classifier__max_iter=1000, classifier__solver=liblinear; total time=  16.0s
# Best parameters: {'classifier__C': 10, 'classifier__max_iter': 1000, 'classifier__solver': 'liblinear'}
#               precision    recall  f1-score   support
#
#         ENFJ       0.68      0.39      0.50        38
#         ENFP       0.66      0.61      0.64       135
#         ENTJ       0.68      0.37      0.48        46
#         ENTP       0.63      0.59      0.61       137
#         ESFJ       0.67      0.50      0.57         8
#         ESFP       1.00      0.10      0.18        10
#         ESTJ       1.00      0.12      0.22         8
#         ESTP       0.43      0.33      0.38        18
#         INFJ       0.67      0.74      0.70       294
#         INFP       0.68      0.80      0.73       367
#         INTJ       0.63      0.72      0.67       218
#         INTP       0.68      0.75      0.72       261
#         ISFJ       0.75      0.45      0.57        33
#         ISFP       0.64      0.43      0.51        54
#         ISTJ       0.68      0.32      0.43        41
#         ISTP       0.67      0.46      0.55        67
#
#     accuracy                           0.66      1735
#    macro avg       0.70      0.48      0.53      1735
# weighted avg       0.67      0.66      0.65      1735
#
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END classifier__C=10, classifier__max_iter=1000, classifier__solver=liblinear; total time=  24.5s
# [CV] END classifier__C=10, classifier__max_iter=1000, classifier__solver=liblinear; total time=  29.2s
# [CV] END classifier__C=10, classifier__max_iter=1000, classifier__solver=liblinear; total time=  30.1s
# [CV] END classifier__C=10, classifier__max_iter=1000, classifier__solver=liblinear; total time=  30.6s
# [CV] END classifier__C=10, classifier__max_iter=1000, classifier__solver=liblinear; total time=  13.7s
# Best parameters: {'classifier__C': 10, 'classifier__max_iter': 1000, 'classifier__solver': 'liblinear'}
#               precision    recall  f1-score   support
#
#         ENFJ       0.76      0.34      0.47        38
#         ENFP       0.64      0.61      0.63       135
#         ENTJ       0.72      0.46      0.56        46
#         ENTP       0.67      0.64      0.65       137
#         ESFJ       0.50      0.33      0.40         9
#         ESFP       1.00      0.10      0.18        10
#         ESTJ       0.67      0.29      0.40         7
#         ESTP       0.67      0.22      0.33        18
#         INFJ       0.61      0.66      0.63       294
#         INFP       0.64      0.79      0.71       366
#         INTJ       0.61      0.62      0.62       218
#         INTP       0.63      0.69      0.66       261
#         ISFJ       0.82      0.42      0.56        33
#         ISFP       0.59      0.40      0.48        55
#         ISTJ       0.64      0.44      0.52        41
#         ISTP       0.67      0.52      0.59        67
#
#     accuracy                           0.64      1735
#    macro avg       0.68      0.47      0.52      1735
# weighted avg       0.64      0.64      0.63      1735
#
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END classifier__C=10, classifier__max_iter=1000, classifier__solver=liblinear; total time=  24.9s
# [CV] END classifier__C=10, classifier__max_iter=1000, classifier__solver=liblinear; total time=  27.5s
# [CV] END classifier__C=10, classifier__max_iter=1000, classifier__solver=liblinear; total time=  29.1s
# [CV] END classifier__C=10, classifier__max_iter=1000, classifier__solver=liblinear; total time=  29.7s
# [CV] END classifier__C=10, classifier__max_iter=1000, classifier__solver=liblinear; total time=  13.0s
# Best parameters: {'classifier__C': 10, 'classifier__max_iter': 1000, 'classifier__solver': 'liblinear'}
#               precision    recall  f1-score   support
#
#         ENFJ       0.62      0.26      0.37        38
#         ENFP       0.63      0.56      0.59       135
#         ENTJ       0.59      0.35      0.44        46
#         ENTP       0.63      0.57      0.60       137
#         ESFJ       0.00      0.00      0.00         9
#         ESFP       0.00      0.00      0.00         9
#         ESTJ       1.00      0.12      0.22         8
#         ESTP       0.80      0.22      0.35        18
#         INFJ       0.62      0.67      0.65       294
#         INFP       0.61      0.78      0.69       366
#         INTJ       0.65      0.63      0.64       219
#         INTP       0.65      0.76      0.70       260
#         ISFJ       0.85      0.52      0.64        33
#         ISFP       0.67      0.52      0.58        54
#         ISTJ       0.81      0.41      0.55        41
#         ISTP       0.68      0.65      0.66        68
#
#     accuracy                           0.64      1735
#    macro avg       0.61      0.44      0.48      1735
# weighted avg       0.64      0.64      0.63      1735
# ['best_model_pipeline.pkl']

# %%
results = grid_search.best_estimator_.predict(["I feel so tired today"])
decoded = encoder.inverse_transform(results)
decoded
# Out:
# array(['INFP'], dtype=object)

# %%
results = grid_search.best_estimator_.predict_proba(["I feel so tired today"])

for index in range(16):
    print(encoder.inverse_transform([index]), results[0][index])
# Out:
# ['ENFJ'] 0.006501841384795359
# ['ENFP'] 0.0033455879785575537
# ['ENTJ'] 0.018341351479867502
# ['ENTP'] 0.004449597256039055
# ['ESFJ'] 0.0030376229343223402
# ['ESFP'] 0.012279221585312524
# ['ESTJ'] 0.004692909357345497
# ['ESTP'] 0.0014148845446219699
# ['INFJ'] 0.1280410616863811
# ['INFP'] 0.7576781540703091
# ['INTJ'] 0.00846308543954056
# ['INTP'] 0.025556921120510674
# ['ISFJ'] 0.015766500823655796
# ['ISFP'] 0.005553521354262769
# ['ISTJ'] 0.003371218206668025
# ['ISTP'] 0.001506520777809998
